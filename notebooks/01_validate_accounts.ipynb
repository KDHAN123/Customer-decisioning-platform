# %%
import pandas as pd

accounts = pd.read_parquet("../data/raw/accounts.parquet")

accounts.head()
# Out:
#                              account_id  account_number  \
# 0  192b4d3c-432e-4a08-9c6f-c33bd7a1112d               1
# 1  87a5dad7-0a1d-43e7-b457-40bfd0b8703b               2
# 2  8374010d-30c1-4668-8378-fad28dd898a3               3
# 3  a5e35881-2c71-43f2-b934-de10a3af614e               4
# 4  007dc0f0-6ae1-4f43-ac59-11f55d2fa39d               5
#
#                       company_name            industry company_size  \
# 0  Rodriguez, Figueroa and Sanchez  Financial Services         1-10
# 1                        Doyle Ltd  Financial Services     501-1000
# 2    Mcclain, Miller and Henderson            Software     501-1000
# 3                   Davis and Sons              Retail      201-500
# 4      Guzman, Hoffman and Baldwin               Media       51-200
#
#          country acquisition_channel signup_date                 created_at  \
# 0         Canada         Paid Search  2026-04-27 2026-04-27 17:31:25.905951
# 1  United States      Organic Search  2024-10-24 2024-10-24 17:31:25.906313
# 2  United States              Direct  2025-03-07 2025-03-07 17:31:25.906430
# 3  United States             Webinar  2025-09-14 2025-09-14 17:31:25.906666
# 4  United States         Paid Search  2024-12-22 2024-12-22 17:31:25.906759
#
#    is_active
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False

# %%
accounts.shape
# Out:
# (2000, 10)

# %%
accounts.isna().sum()
# Out:
# account_id             0
# account_number         0
# company_name           0
# industry               0
# company_size           0
# country                0
# acquisition_channel    0
# signup_date            0
# created_at             0
# is_active              0
# dtype: int64

# %%
accounts["is_active"].value_counts(normalize=True).round(3)
# Out:
# is_active
# True     0.875
# False    0.125
# Name: proportion, dtype: float64
